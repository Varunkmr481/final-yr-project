# %%
import os
import shutil
from pathlib import Path
from random import shuffle

# ---------------- CONFIG ----------------
lfw_raw_path = 'lfw'           # Folder where raw LFW is extracted
output_train = 'lfw_train'
output_test = 'lfw_test'
images_per_person_train = 3
role_prefix = 'student'        # Folder format: student-name
min_images_required = 4        # Keep identities with at least 4 images

# ----------------------------------------
# Create output directories
Path(output_train).mkdir(exist_ok=True)
Path(output_test).mkdir(exist_ok=True)

# Loop through each person in LFW
for person in os.listdir(lfw_raw_path):
    person_dir = os.path.join(lfw_raw_path, person)
    if not os.path.isdir(person_dir):
        continue

    images = os.listdir(person_dir)
    if len(images) < min_images_required:
        continue  # Skip identities with too few images

    shuffle(images)
    train_imgs = images[:images_per_person_train]
    test_imgs = images[images_per_person_train:]

    # ✅ Clean person name: lowercase + replace spaces with underscores
    person_clean = person.lower().replace(' ', '_')
    folder_name = f"{role_prefix}-{person_clean}"  # e.g., student-amer_al_saadi

    # Create train folder and copy images
    train_path = os.path.join(output_train, folder_name)
    Path(train_path).mkdir(parents=True, exist_ok=True)
    for img in train_imgs:
        shutil.copy(os.path.join(person_dir, img), os.path.join(train_path, img))

    # Create test folder and copy images
    test_path = os.path.join(output_test, folder_name)
    Path(test_path).mkdir(parents=True, exist_ok=True)
    for img in test_imgs:
        shutil.copy(os.path.join(person_dir, img), os.path.join(test_path, img))

print("✅ LFW restructuring complete with underscores in folder names.")
print(f"Training data saved in: {output_train}")
print(f"Testing data saved in: {output_test}")
# Out:
# ✅ LFW restructuring complete with underscores in folder names.
# Training data saved in: lfw_train
# Testing data saved in: lfw_test

# %%
import os

# --------------- CONFIG ----------------
base_dir = 'lfw_test'  # or 'lfw_test', 'images', etc.

# --------------- RENAME FOLDERS ----------------
for folder_name in os.listdir(base_dir):
    old_path = os.path.join(base_dir, folder_name)

    if os.path.isdir(old_path) and folder_name.startswith('student-'):
        prefix = 'student-'
        name_part = folder_name[len(prefix):]
        name_with_underscores = name_part.replace(' ', '_')
        new_folder_name = prefix + name_with_underscores
        new_path = os.path.join(base_dir, new_folder_name)

        if new_folder_name != folder_name:
            os.rename(old_path, new_path)
            print(f"✅ Renamed: {folder_name} → {new_folder_name}")
        else:
            print(f"ℹ️ No change needed: {folder_name}")

print("\n🎉 All matching folder names have been updated.")
# Out:
# ✅ Renamed: student-aaron peirsol → student-aaron_peirsol
# ✅ Renamed: student-abdoulaye wade → student-abdoulaye_wade
# ℹ️ No change needed: student-abdullah
# ✅ Renamed: student-abdullah gul → student-abdullah_gul
# ✅ Renamed: student-abel pacheco → student-abel_pacheco
# ✅ Renamed: student-adam sandler → student-adam_sandler
# ✅ Renamed: student-adrien brody → student-adrien_brody
# ✅ Renamed: student-ahmed chalabi → student-ahmed_chalabi
# ✅ Renamed: student-ai sugiyama → student-ai_sugiyama
# ✅ Renamed: student-al gore → student-al_gore
# ✅ Renamed: student-al sharpton → student-al_sharpton
# ✅ Renamed: student-alan greenspan → student-alan_greenspan
# ✅ Renamed: student-alastair campbell → student-alastair_campbell
# ✅ Renamed: student-albert costa → student-albert_costa
# ✅ Renamed: student-alec baldwin → student-alec_baldwin
# ✅ Renamed: student-alejandro toledo → student-alejandro_toledo
# ✅ Renamed: student-aleksander kwasniewski → student-aleksander_kwasniewski
# ✅ Renamed: student-alexander downer → student-alexander_downer
# ✅ Renamed: student-alexander losyukov → student-alexander_losyukov
# ✅ Renamed: student-ali naimi → student-ali_naimi
# ✅ Renamed: student-allyson felix → student-allyson_felix
# ✅ Renamed: student-alvaro silva calderon → student-alvaro_silva_calderon
# ✅ Renamed: student-alvaro uribe → student-alvaro_uribe
# ✅ Renamed: student-amanda bynes → student-amanda_bynes
# ✅ Renamed: student-amelia vega → student-amelia_vega
# ✅ Renamed: student-amelie mauresmo → student-amelie_mauresmo
# ✅ Renamed: student-amer al-saadi → student-amer_al-saadi
# ✅ Renamed: student-ana guevara → student-ana_guevara
# ✅ Renamed: student-ana palacio → student-ana_palacio
# ✅ Renamed: student-anders fogh rasmussen → student-anders_fogh_rasmussen
# ✅ Renamed: student-andre agassi → student-andre_agassi
# ✅ Renamed: student-andy roddick → student-andy_roddick
# ✅ Renamed: student-angela bassett → student-angela_bassett
# ✅ Renamed: student-angela merkel → student-angela_merkel
# ✅ Renamed: student-angelina jolie → student-angelina_jolie
# ✅ Renamed: student-angelo reyes → student-angelo_reyes
# ✅ Renamed: student-ann veneman → student-ann_veneman
# ✅ Renamed: student-anna kournikova → student-anna_kournikova
# ✅ Renamed: student-antonio banderas → student-antonio_banderas
# ✅ Renamed: student-antonio palocci → student-antonio_palocci
# ✅ Renamed: student-antony leung → student-antony_leung
# ✅ Renamed: student-ari fleischer → student-ari_fleischer
# ✅ Renamed: student-arianna huffington → student-arianna_huffington
# ✅ Renamed: student-ariel sharon → student-ariel_sharon
# ✅ Renamed: student-arminio fraga → student-arminio_fraga
# ✅ Renamed: student-arnold schwarzenegger → student-arnold_schwarzenegger
# ✅ Renamed: student-arnoldo aleman → student-arnoldo_aleman
# ✅ Renamed: student-art howe → student-art_howe
# ℹ️ No change needed: student-ashanti
# ✅ Renamed: student-atal bihari vajpayee → student-atal_bihari_vajpayee
# ✅ Renamed: student-augustin calleri → student-augustin_calleri
# ✅ Renamed: student-azra akin → student-azra_akin
# ✅ Renamed: student-barbara walters → student-barbara_walters
# ✅ Renamed: student-bashar assad → student-bashar_assad
# ✅ Renamed: student-ben affleck → student-ben_affleck
# ✅ Renamed: student-ben howland → student-ben_howland
# ✅ Renamed: student-benazir bhutto → student-benazir_bhutto
# ✅ Renamed: student-benjamin netanyahu → student-benjamin_netanyahu
# ✅ Renamed: student-bernard landry → student-bernard_landry
# ✅ Renamed: student-bernard law → student-bernard_law
# ✅ Renamed: student-bertie ahern → student-bertie_ahern
# ✅ Renamed: student-bill clinton → student-bill_clinton
# ✅ Renamed: student-bill frist → student-bill_frist
# ✅ Renamed: student-bill gates → student-bill_gates
# ✅ Renamed: student-bill graham → student-bill_graham
# ✅ Renamed: student-bill mcbride → student-bill_mcbride
# ✅ Renamed: student-bill paxton → student-bill_paxton
# ✅ Renamed: student-bill simon → student-bill_simon
# ✅ Renamed: student-billy crystal → student-billy_crystal
# ✅ Renamed: student-binyamin ben-eliezer → student-binyamin_ben-eliezer
# ✅ Renamed: student-bob graham → student-bob_graham
# ✅ Renamed: student-bob hope → student-bob_hope
# ✅ Renamed: student-bob huggins → student-bob_huggins
# ✅ Renamed: student-bob stoops → student-bob_stoops
# ✅ Renamed: student-boris becker → student-boris_becker
# ✅ Renamed: student-brad garrett → student-brad_garrett
# ✅ Renamed: student-brad johnson → student-brad_johnson
# ✅ Renamed: student-britney spears → student-britney_spears
# ✅ Renamed: student-bruce springsteen → student-bruce_springsteen
# ✅ Renamed: student-bud selig → student-bud_selig
# ✅ Renamed: student-bulent ecevit → student-bulent_ecevit
# ✅ Renamed: student-calista flockhart → student-calista_flockhart
# ✅ Renamed: student-cameron diaz → student-cameron_diaz
# ✅ Renamed: student-candie kung → student-candie_kung
# ✅ Renamed: student-carla del ponte → student-carla_del_ponte
# ✅ Renamed: student-carlos menem → student-carlos_menem
# ✅ Renamed: student-carlos moya → student-carlos_moya
# ✅ Renamed: student-carlos vives → student-carlos_vives
# ✅ Renamed: student-carmen electra → student-carmen_electra
# ✅ Renamed: student-carrie-anne moss → student-carrie-anne_moss
# ✅ Renamed: student-carson palmer → student-carson_palmer
# ✅ Renamed: student-cate blanchett → student-cate_blanchett
# ✅ Renamed: student-catherine deneuve → student-catherine_deneuve
# ✅ Renamed: student-catherine zeta-jones → student-catherine_zeta-jones
# ✅ Renamed: student-celine dion → student-celine_dion
# ✅ Renamed: student-cesar gaviria → student-cesar_gaviria
# ✅ Renamed: student-chanda rubin → student-chanda_rubin
# ✅ Renamed: student-charles moose → student-charles_moose
# ✅ Renamed: student-charles taylor → student-charles_taylor
# ✅ Renamed: student-charlton heston → student-charlton_heston
# ✅ Renamed: student-chen shui-bian → student-chen_shui-bian
# ✅ Renamed: student-cherie blair → student-cherie_blair
# ✅ Renamed: student-choi sung-hong → student-choi_sung-hong
# ✅ Renamed: student-christina aguilera → student-christina_aguilera
# ✅ Renamed: student-christine baumgartner → student-christine_baumgartner
# ✅ Renamed: student-christine gregoire → student-christine_gregoire
# ✅ Renamed: student-christine todd whitman → student-christine_todd_whitman
# ✅ Renamed: student-christopher reeve → student-christopher_reeve
# ✅ Renamed: student-christopher walken → student-christopher_walken
# ✅ Renamed: student-ciro gomes → student-ciro_gomes
# ✅ Renamed: student-clara harris → student-clara_harris
# ✅ Renamed: student-clare short → student-clare_short
# ✅ Renamed: student-claudia pechstein → student-claudia_pechstein
# ✅ Renamed: student-clay aiken → student-clay_aiken
# ✅ Renamed: student-clint eastwood → student-clint_eastwood
# ✅ Renamed: student-colin farrell → student-colin_farrell
# ✅ Renamed: student-colin montgomerie → student-colin_montgomerie
# ✅ Renamed: student-colin powell → student-colin_powell
# ✅ Renamed: student-conan obrien → student-conan_obrien
# ✅ Renamed: student-condoleezza rice → student-condoleezza_rice
# ✅ Renamed: student-costas simitis → student-costas_simitis
# ✅ Renamed: student-cruz bustamante → student-cruz_bustamante
# ✅ Renamed: student-daisy fuentes → student-daisy_fuentes
# ✅ Renamed: student-dale earnhardt jr → student-dale_earnhardt_jr
# ✅ Renamed: student-daniel radcliffe → student-daniel_radcliffe
# ✅ Renamed: student-david anderson → student-david_anderson
# ✅ Renamed: student-david beckham → student-david_beckham
# ✅ Renamed: student-david heymann → student-david_heymann
# ✅ Renamed: student-david hyde pierce → student-david_hyde_pierce
# ✅ Renamed: student-david nalbandian → student-david_nalbandian
# ✅ Renamed: student-david stern → student-david_stern
# ✅ Renamed: student-david trimble → student-david_trimble
# ✅ Renamed: student-david wells → student-david_wells
# ✅ Renamed: student-dean barkley → student-dean_barkley
# ✅ Renamed: student-debbie reynolds → student-debbie_reynolds
# ✅ Renamed: student-demi moore → student-demi_moore
# ✅ Renamed: student-dennis hastert → student-dennis_hastert
# ✅ Renamed: student-dennis kucinich → student-dennis_kucinich
# ✅ Renamed: student-denzel washington → student-denzel_washington
# ✅ Renamed: student-derek jeter → student-derek_jeter
# ✅ Renamed: student-diana krall → student-diana_krall
# ✅ Renamed: student-dick cheney → student-dick_cheney
# ✅ Renamed: student-dominique de villepin → student-dominique_de_villepin
# ✅ Renamed: student-don siegelman → student-don_siegelman
# ✅ Renamed: student-donald fehr → student-donald_fehr
# ✅ Renamed: student-donald rumsfeld → student-donald_rumsfeld
# ✅ Renamed: student-doris schroeder → student-doris_schroeder
# ✅ Renamed: student-edmund stoiber → student-edmund_stoiber
# ✅ Renamed: student-eduard shevardnadze → student-eduard_shevardnadze
# ✅ Renamed: student-eduardo duhalde → student-eduardo_duhalde
# ✅ Renamed: student-edward lu → student-edward_lu
# ✅ Renamed: student-edwina currie → student-edwina_currie
# ✅ Renamed: student-eliane karp → student-eliane_karp
# ✅ Renamed: student-elizabeth dole → student-elizabeth_dole
# ✅ Renamed: student-elizabeth hurley → student-elizabeth_hurley
# ✅ Renamed: student-elizabeth smart → student-elizabeth_smart
# ✅ Renamed: student-elsa zylberstein → student-elsa_zylberstein
# ✅ Renamed: student-elton john → student-elton_john
# ✅ Renamed: student-emanuel ginobili → student-emanuel_ginobili
# ✅ Renamed: student-emma watson → student-emma_watson
# ✅ Renamed: student-enrique bolanos → student-enrique_bolanos
# ✅ Renamed: student-erika harold → student-erika_harold
# ✅ Renamed: student-erin runnion → student-erin_runnion
# ✅ Renamed: student-ernie els → student-ernie_els
# ✅ Renamed: student-ethan hawke → student-ethan_hawke
# ✅ Renamed: student-fayssal mekdad → student-fayssal_mekdad
# ✅ Renamed: student-felipe perez roque → student-felipe_perez_roque
# ✅ Renamed: student-fernando gonzalez → student-fernando_gonzalez
# ✅ Renamed: student-fernando henrique cardoso → student-fernando_henrique_cardoso
# ✅ Renamed: student-fernando vargas → student-fernando_vargas
# ✅ Renamed: student-fidel castro → student-fidel_castro
# ✅ Renamed: student-francisco flores → student-francisco_flores
# ✅ Renamed: student-frank solich → student-frank_solich
# ✅ Renamed: student-franz fischler → student-franz_fischler
# ✅ Renamed: student-franz muentefering → student-franz_muentefering
# ✅ Renamed: student-fujio cho → student-fujio_cho
# ✅ Renamed: student-gene robinson → student-gene_robinson
# ✅ Renamed: student-geoff hoon → student-geoff_hoon
# ✅ Renamed: student-george clooney → student-george_clooney
# ✅ Renamed: student-george galloway → student-george_galloway
# ✅ Renamed: student-george hw bush → student-george_hw_bush
# ✅ Renamed: student-george lopez → student-george_lopez
# ✅ Renamed: student-george papandreou → student-george_papandreou
# ✅ Renamed: student-george pataki → student-george_pataki
# ✅ Renamed: student-george robertson → student-george_robertson
# ✅ Renamed: student-george ryan → student-george_ryan
# ✅ Renamed: student-george w bush → student-george_w_bush
# ✅ Renamed: student-geraldine chaplin → student-geraldine_chaplin
# ✅ Renamed: student-gerhard schroeder → student-gerhard_schroeder
# ✅ Renamed: student-gerry adams → student-gerry_adams
# ✅ Renamed: student-gil de ferran → student-gil_de_ferran
# ✅ Renamed: student-gilberto rodriguez orejuela → student-gilberto_rodriguez_orejuela
# ✅ Renamed: student-giuseppe gibilisco → student-giuseppe_gibilisco
# ✅ Renamed: student-gl peiris → student-gl_peiris
# ✅ Renamed: student-glafcos clerides → student-glafcos_clerides
# ✅ Renamed: student-gloria macapagal arroyo → student-gloria_macapagal_arroyo
# ✅ Renamed: student-gloria trevi → student-gloria_trevi
# ✅ Renamed: student-goldie hawn → student-goldie_hawn
# ✅ Renamed: student-gonzalo sanchez de lozada → student-gonzalo_sanchez_de_lozada
# ✅ Renamed: student-gordon brown → student-gordon_brown
# ✅ Renamed: student-grant hackett → student-grant_hackett
# ✅ Renamed: student-gray davis → student-gray_davis
# ✅ Renamed: student-greg rusedski → student-greg_rusedski
# ✅ Renamed: student-gregg popovich → student-gregg_popovich
# ✅ Renamed: student-guillermo canas → student-guillermo_canas
# ✅ Renamed: student-guillermo coria → student-guillermo_coria
# ✅ Renamed: student-gunter pleuger → student-gunter_pleuger
# ✅ Renamed: student-gwyneth paltrow → student-gwyneth_paltrow
# ✅ Renamed: student-habib rizieq → student-habib_rizieq
# ✅ Renamed: student-hal gehman → student-hal_gehman
# ✅ Renamed: student-halle berry → student-halle_berry
# ✅ Renamed: student-hamid karzai → student-hamid_karzai
# ✅ Renamed: student-hans blix → student-hans_blix
# ✅ Renamed: student-harrison ford → student-harrison_ford
# ✅ Renamed: student-harry schmidt → student-harry_schmidt
# ✅ Renamed: student-heath ledger → student-heath_ledger
# ✅ Renamed: student-heather mills → student-heather_mills
# ✅ Renamed: student-heidi fleiss → student-heidi_fleiss
# ✅ Renamed: student-heidi klum → student-heidi_klum
# ✅ Renamed: student-heizo takenaka → student-heizo_takenaka
# ✅ Renamed: student-helen clark → student-helen_clark
# ✅ Renamed: student-herb sendek → student-herb_sendek
# ✅ Renamed: student-hillary clinton → student-hillary_clinton
# ✅ Renamed: student-hipolito mejia → student-hipolito_mejia
# ✅ Renamed: student-hitomi soga → student-hitomi_soga
# ✅ Renamed: student-holly hunter → student-holly_hunter
# ✅ Renamed: student-hosni mubarak → student-hosni_mubarak
# ✅ Renamed: student-howard dean → student-howard_dean
# ✅ Renamed: student-hu jintao → student-hu_jintao
# ✅ Renamed: student-hugh grant → student-hugh_grant
# ✅ Renamed: student-hugo chavez → student-hugo_chavez
# ✅ Renamed: student-hun sen → student-hun_sen
# ✅ Renamed: student-iain duncan smith → student-iain_duncan_smith
# ✅ Renamed: student-ian thorpe → student-ian_thorpe
# ✅ Renamed: student-igor ivanov → student-igor_ivanov
# ✅ Renamed: student-jack straw → student-jack_straw
# ✅ Renamed: student-jackie chan → student-jackie_chan
# ✅ Renamed: student-jacques chirac → student-jacques_chirac
# ✅ Renamed: student-jacques rogge → student-jacques_rogge
# ✅ Renamed: student-jake gyllenhaal → student-jake_gyllenhaal
# ✅ Renamed: student-james blake → student-james_blake
# ✅ Renamed: student-james kelly → student-james_kelly
# ✅ Renamed: student-james kopp → student-james_kopp
# ✅ Renamed: student-james mcgreevey → student-james_mcgreevey
# ✅ Renamed: student-james wolfensohn → student-james_wolfensohn
# ✅ Renamed: student-jan ullrich → student-jan_ullrich
# ✅ Renamed: student-janet napolitano → student-janet_napolitano
# ✅ Renamed: student-jason kidd → student-jason_kidd
# ✅ Renamed: student-javier solana → student-javier_solana
# ✅ Renamed: student-jay garner → student-jay_garner
# ✅ Renamed: student-jean charest → student-jean_charest
# ✅ Renamed: student-jean chretien → student-jean_chretien
# ✅ Renamed: student-jean-david levitte → student-jean-david_levitte
# ✅ Renamed: student-jean-pierre raffarin → student-jean-pierre_raffarin
# ✅ Renamed: student-jeb bush → student-jeb_bush
# ✅ Renamed: student-jelena dokic → student-jelena_dokic
# ✅ Renamed: student-jennifer aniston → student-jennifer_aniston
# ✅ Renamed: student-jennifer capriati → student-jennifer_capriati
# ✅ Renamed: student-jennifer connelly → student-jennifer_connelly
# ✅ Renamed: student-jennifer garner → student-jennifer_garner
# ✅ Renamed: student-jennifer keller → student-jennifer_keller
# ✅ Renamed: student-jennifer lopez → student-jennifer_lopez
# ✅ Renamed: student-jeong se-hyun → student-jeong_se-hyun
# ✅ Renamed: student-jeremy greenstock → student-jeremy_greenstock
# ✅ Renamed: student-jerry regier → student-jerry_regier
# ✅ Renamed: student-jerry springer → student-jerry_springer
# ✅ Renamed: student-jesse jackson → student-jesse_jackson
# ✅ Renamed: student-jiang zemin → student-jiang_zemin
# ✅ Renamed: student-jim furyk → student-jim_furyk
# ✅ Renamed: student-jim hahn → student-jim_hahn
# ✅ Renamed: student-jim tressel → student-jim_tressel
# ✅ Renamed: student-jimmy carter → student-jimmy_carter
# ✅ Renamed: student-jiri novak → student-jiri_novak
# ✅ Renamed: student-jk rowling → student-jk_rowling
# ✅ Renamed: student-joan laporta → student-joan_laporta
# ✅ Renamed: student-joe lieberman → student-joe_lieberman
# ✅ Renamed: student-joe nichols → student-joe_nichols
# ✅ Renamed: student-joe torre → student-joe_torre
# ✅ Renamed: student-john abizaid → student-john_abizaid
# ✅ Renamed: student-john allen muhammad → student-john_allen_muhammad
# ✅ Renamed: student-john ashcroft → student-john_ashcroft
# ✅ Renamed: student-john bolton → student-john_bolton
# ✅ Renamed: student-john edwards → student-john_edwards
# ✅ Renamed: student-john howard → student-john_howard
# ✅ Renamed: student-john kerry → student-john_kerry
# ✅ Renamed: student-john manley → student-john_manley
# ✅ Renamed: student-john mccain → student-john_mccain
# ✅ Renamed: student-john negroponte → student-john_negroponte
# ✅ Renamed: student-john paul ii → student-john_paul_ii
# ✅ Renamed: student-john snow → student-john_snow
# ✅ Renamed: student-john stockton → student-john_stockton
# ✅ Renamed: student-john travolta → student-john_travolta
# ✅ Renamed: student-john warner → student-john_warner
# ✅ Renamed: student-jon gruden → student-jon_gruden
# ✅ Renamed: student-jonathan edwards → student-jonathan_edwards
# ✅ Renamed: student-jong wook lee → student-jong_wook_lee
# ✅ Renamed: student-joschka fischer → student-joschka_fischer
# ✅ Renamed: student-jose manuel durao barroso → student-jose_manuel_durao_barroso
# ✅ Renamed: student-jose maria aznar → student-jose_maria_aznar
# ✅ Renamed: student-jose serra → student-jose_serra
# ✅ Renamed: student-joseph biden → student-joseph_biden
# ✅ Renamed: student-joseph estrada → student-joseph_estrada
# ✅ Renamed: student-juan carlos ferrero → student-juan_carlos_ferrero
# ✅ Renamed: student-juan pablo montoya → student-juan_pablo_montoya
# ✅ Renamed: student-julianne moore → student-julianne_moore
# ✅ Renamed: student-julie gerberding → student-julie_gerberding
# ✅ Renamed: student-junichiro koizumi → student-junichiro_koizumi
# ✅ Renamed: student-justin leonard → student-justin_leonard
# ✅ Renamed: student-justin timberlake → student-justin_timberlake
# ✅ Renamed: student-justine pasek → student-justine_pasek
# ✅ Renamed: student-kalpana chawla → student-kalpana_chawla
# ✅ Renamed: student-kamal kharrazi → student-kamal_kharrazi
# ✅ Renamed: student-kate hudson → student-kate_hudson
# ✅ Renamed: student-kate winslet → student-kate_winslet
# ✅ Renamed: student-katherine harris → student-katherine_harris
# ✅ Renamed: student-kathleen kennedy townsend → student-kathleen_kennedy_townsend
# ✅ Renamed: student-keanu reeves → student-keanu_reeves
# ✅ Renamed: student-kevin costner → student-kevin_costner
# ✅ Renamed: student-kevin spacey → student-kevin_spacey
# ✅ Renamed: student-kim clijsters → student-kim_clijsters
# ✅ Renamed: student-kim dae-jung → student-kim_dae-jung
# ✅ Renamed: student-kim jong-il → student-kim_jong-il
# ✅ Renamed: student-kim ryong-sung → student-kim_ryong-sung
# ✅ Renamed: student-king abdullah ii → student-king_abdullah_ii
# ✅ Renamed: student-kofi annan → student-kofi_annan
# ✅ Renamed: student-kristanna loken → student-kristanna_loken
# ✅ Renamed: student-kurt warner → student-kurt_warner
# ✅ Renamed: student-lance armstrong → student-lance_armstrong
# ✅ Renamed: student-lance bass → student-lance_bass
# ✅ Renamed: student-larry brown → student-larry_brown
# ✅ Renamed: student-larry coker → student-larry_coker
# ✅ Renamed: student-larry thompson → student-larry_thompson
# ✅ Renamed: student-laura bush → student-laura_bush
# ✅ Renamed: student-laura linney → student-laura_linney
# ✅ Renamed: student-lebron james → student-lebron_james
# ✅ Renamed: student-lee hoi-chang → student-lee_hoi-chang
# ✅ Renamed: student-leonardo dicaprio → student-leonardo_dicaprio
# ✅ Renamed: student-leonid kuchma → student-leonid_kuchma
# ✅ Renamed: student-li peng → student-li_peng
# ✅ Renamed: student-li zhaoxing → student-li_zhaoxing
# ✅ Renamed: student-lindsay davenport → student-lindsay_davenport
# ✅ Renamed: student-lisa marie presley → student-lisa_marie_presley
# ✅ Renamed: student-liza minnelli → student-liza_minnelli
# ✅ Renamed: student-lleyton hewitt → student-lleyton_hewitt
# ✅ Renamed: student-lucio gutierrez → student-lucio_gutierrez
# ✅ Renamed: student-lucy liu → student-lucy_liu
# ✅ Renamed: student-ludivine sagnier → student-ludivine_sagnier
# ✅ Renamed: student-luis ernesto derbez bautista → student-luis_ernesto_derbez_bautista
# ✅ Renamed: student-luis figo → student-luis_figo
# ✅ Renamed: student-luis gonzalez macchi → student-luis_gonzalez_macchi
# ✅ Renamed: student-luis horna → student-luis_horna
# ✅ Renamed: student-luiz inacio lula da silva → student-luiz_inacio_lula_da_silva
# ℹ️ No change needed: student-madonna
# ✅ Renamed: student-mahathir mohamad → student-mahathir_mohamad
# ✅ Renamed: student-mahmoud abbas → student-mahmoud_abbas
# ✅ Renamed: student-marc grossman → student-marc_grossman
# ✅ Renamed: student-marcelo rios → student-marcelo_rios
# ✅ Renamed: student-marco antonio barrera → student-marco_antonio_barrera
# ✅ Renamed: student-maria shriver → student-maria_shriver
# ✅ Renamed: student-maria soledad alvear valenzuela → student-maria_soledad_alvear_valenzuela
# ✅ Renamed: student-mariah carey → student-mariah_carey
# ✅ Renamed: student-mark hurlbert → student-mark_hurlbert
# ✅ Renamed: student-mark philippoussis → student-mark_philippoussis
# ✅ Renamed: student-mark wahlberg → student-mark_wahlberg
# ✅ Renamed: student-martha burk → student-martha_burk
# ✅ Renamed: student-martha lucia ramirez → student-martha_lucia_ramirez
# ✅ Renamed: student-martha stewart → student-martha_stewart
# ✅ Renamed: student-martin mcguinness → student-martin_mcguinness
# ✅ Renamed: student-martin scorsese → student-martin_scorsese
# ✅ Renamed: student-martina mcbride → student-martina_mcbride
# ✅ Renamed: student-mary carey → student-mary_carey
# ✅ Renamed: student-matt damon → student-matt_damon
# ✅ Renamed: student-matthew broderick → student-matthew_broderick
# ✅ Renamed: student-matthew perry → student-matthew_perry
# ✅ Renamed: student-megawati sukarnoputri → student-megawati_sukarnoputri
# ✅ Renamed: student-meryl streep → student-meryl_streep
# ✅ Renamed: student-mian khursheed mehmood kasuri → student-mian_khursheed_mehmood_kasuri
# ✅ Renamed: student-michael bloomberg → student-michael_bloomberg
# ✅ Renamed: student-michael caine → student-michael_caine
# ✅ Renamed: student-michael chang → student-michael_chang
# ✅ Renamed: student-michael chiklis → student-michael_chiklis
# ✅ Renamed: student-michael douglas → student-michael_douglas
# ✅ Renamed: student-michael jackson → student-michael_jackson
# ✅ Renamed: student-michael jordan → student-michael_jordan
# ✅ Renamed: student-michael phelps → student-michael_phelps
# ✅ Renamed: student-michael powell → student-michael_powell
# ✅ Renamed: student-michael schumacher → student-michael_schumacher
# ✅ Renamed: student-michelle kwan → student-michelle_kwan
# ✅ Renamed: student-michelle yeoh → student-michelle_yeoh
# ✅ Renamed: student-mick jagger → student-mick_jagger
# ✅ Renamed: student-mike krzyzewski → student-mike_krzyzewski
# ✅ Renamed: student-mike martz → student-mike_martz
# ✅ Renamed: student-mike myers → student-mike_myers
# ✅ Renamed: student-mike tyson → student-mike_tyson
# ✅ Renamed: student-mike weir → student-mike_weir
# ✅ Renamed: student-mikhail kasyanov → student-mikhail_kasyanov
# ✅ Renamed: student-mikhail wehbe → student-mikhail_wehbe
# ✅ Renamed: student-mireya moscoso → student-mireya_moscoso
# ✅ Renamed: student-mitchell daniels → student-mitchell_daniels
# ✅ Renamed: student-mohamed elbaradei → student-mohamed_elbaradei
# ✅ Renamed: student-mohammad khatami → student-mohammad_khatami
# ✅ Renamed: student-mohammed al-douri → student-mohammed_al-douri
# ✅ Renamed: student-monica bellucci → student-monica_bellucci
# ✅ Renamed: student-monica seles → student-monica_seles
# ✅ Renamed: student-moshe katsav → student-moshe_katsav
# ✅ Renamed: student-muhammad ali → student-muhammad_ali
# ✅ Renamed: student-muhammad saeed al-sahhaf → student-muhammad_saeed_al-sahhaf
# ✅ Renamed: student-nadia petrova → student-nadia_petrova
# ✅ Renamed: student-naji sabri → student-naji_sabri
# ✅ Renamed: student-nan wang → student-nan_wang
# ✅ Renamed: student-nancy pelosi → student-nancy_pelosi
# ✅ Renamed: student-naomi watts → student-naomi_watts
# ✅ Renamed: student-naoto kan → student-naoto_kan
# ✅ Renamed: student-natalie coughlin → student-natalie_coughlin
# ✅ Renamed: student-natalie maines → student-natalie_maines
# ✅ Renamed: student-nathalie baye → student-nathalie_baye
# ✅ Renamed: student-nelson mandela → student-nelson_mandela
# ✅ Renamed: student-nestor kirchner → student-nestor_kirchner
# ✅ Renamed: student-nia vardalos → student-nia_vardalos
# ✅ Renamed: student-nicanor duarte frutos → student-nicanor_duarte_frutos
# ✅ Renamed: student-nick nolte → student-nick_nolte
# ✅ Renamed: student-nicolas cage → student-nicolas_cage
# ✅ Renamed: student-nicole kidman → student-nicole_kidman
# ✅ Renamed: student-noelle bush → student-noelle_bush
# ✅ Renamed: student-norah jones → student-norah_jones
# ✅ Renamed: student-norm coleman → student-norm_coleman
# ✅ Renamed: student-omar sharif → student-omar_sharif
# ✅ Renamed: student-oprah winfrey → student-oprah_winfrey
# ✅ Renamed: student-osama bin laden → student-osama_bin_laden
# ✅ Renamed: student-oscar de la hoya → student-oscar_de_la_hoya
# ✅ Renamed: student-oswaldo paya → student-oswaldo_paya
# ✅ Renamed: student-oxana fedorova → student-oxana_fedorova
# ✅ Renamed: student-padraig harrington → student-padraig_harrington
# ✅ Renamed: student-pamela anderson → student-pamela_anderson
# ✅ Renamed: student-paradorn srichaphan → student-paradorn_srichaphan
# ✅ Renamed: student-patricia clarkson → student-patricia_clarkson
# ✅ Renamed: student-patty schnyder → student-patty_schnyder
# ✅ Renamed: student-paul bremer → student-paul_bremer
# ✅ Renamed: student-paul burrell → student-paul_burrell
# ✅ Renamed: student-paul martin → student-paul_martin
# ✅ Renamed: student-paul mccartney → student-paul_mccartney
# ✅ Renamed: student-paul oneill → student-paul_oneill
# ✅ Renamed: student-paul tagliabue → student-paul_tagliabue
# ✅ Renamed: student-paul wolfowitz → student-paul_wolfowitz
# ✅ Renamed: student-paula radcliffe → student-paula_radcliffe
# ✅ Renamed: student-pedro almodovar → student-pedro_almodovar
# ✅ Renamed: student-pedro malan → student-pedro_malan
# ✅ Renamed: student-pedro solbes → student-pedro_solbes
# ✅ Renamed: student-pervez musharraf → student-pervez_musharraf
# ✅ Renamed: student-pete sampras → student-pete_sampras
# ✅ Renamed: student-peter struck → student-peter_struck
# ✅ Renamed: student-pierce brosnan → student-pierce_brosnan
# ✅ Renamed: student-prince charles → student-prince_charles
# ✅ Renamed: student-prince claus → student-prince_claus
# ✅ Renamed: student-princess caroline → student-princess_caroline
# ✅ Renamed: student-pupi avati → student-pupi_avati
# ✅ Renamed: student-queen beatrix → student-queen_beatrix
# ✅ Renamed: student-queen elizabeth ii → student-queen_elizabeth_ii
# ✅ Renamed: student-queen latifah → student-queen_latifah
# ✅ Renamed: student-queen rania → student-queen_rania
# ✅ Renamed: student-rachel hunter → student-rachel_hunter
# ✅ Renamed: student-rafael ramirez → student-rafael_ramirez
# ✅ Renamed: student-rainer schuettler → student-rainer_schuettler
# ✅ Renamed: student-ralf schumacher → student-ralf_schumacher
# ✅ Renamed: student-raoul ruiz → student-raoul_ruiz
# ✅ Renamed: student-ray romano → student-ray_romano
# ✅ Renamed: student-rebecca romijn-stamos → student-rebecca_romijn-stamos
# ✅ Renamed: student-rebekah chantay revels → student-rebekah_chantay_revels
# ✅ Renamed: student-recep tayyip erdogan → student-recep_tayyip_erdogan
# ✅ Renamed: student-reese witherspoon → student-reese_witherspoon
# ✅ Renamed: student-renee zellweger → student-renee_zellweger
# ✅ Renamed: student-ricardo lagos → student-ricardo_lagos
# ✅ Renamed: student-ricardo sanchez → student-ricardo_sanchez
# ✅ Renamed: student-richard armitage → student-richard_armitage
# ✅ Renamed: student-richard gephardt → student-richard_gephardt
# ✅ Renamed: student-richard gere → student-richard_gere
# ✅ Renamed: student-richard myers → student-richard_myers
# ✅ Renamed: student-richard virenque → student-richard_virenque
# ✅ Renamed: student-rick carlisle → student-rick_carlisle
# ✅ Renamed: student-rick perry → student-rick_perry
# ✅ Renamed: student-rick pitino → student-rick_pitino
# ✅ Renamed: student-rita wilson → student-rita_wilson
# ✅ Renamed: student-rob lowe → student-rob_lowe
# ✅ Renamed: student-rob marshall → student-rob_marshall
# ✅ Renamed: student-robert blake → student-robert_blake
# ✅ Renamed: student-robert de niro → student-robert_de_niro
# ✅ Renamed: student-robert duvall → student-robert_duvall
# ✅ Renamed: student-robert kocharian → student-robert_kocharian
# ✅ Renamed: student-robert mueller → student-robert_mueller
# ✅ Renamed: student-robert redford → student-robert_redford
# ✅ Renamed: student-robert zoellick → student-robert_zoellick
# ✅ Renamed: student-roberto carlos → student-roberto_carlos
# ✅ Renamed: student-roger federer → student-roger_federer
# ✅ Renamed: student-roger moore → student-roger_moore
# ✅ Renamed: student-roh moo-hyun → student-roh_moo-hyun
# ✅ Renamed: student-roman polanski → student-roman_polanski
# ✅ Renamed: student-romano prodi → student-romano_prodi
# ✅ Renamed: student-ron dittemore → student-ron_dittemore
# ✅ Renamed: student-ronaldo luis nazario de lima → student-ronaldo_luis_nazario_de_lima
# ✅ Renamed: student-roy moore → student-roy_moore
# ✅ Renamed: student-roy williams → student-roy_williams
# ✅ Renamed: student-rubens barrichello → student-rubens_barrichello
# ✅ Renamed: student-rudolph giuliani → student-rudolph_giuliani
# ✅ Renamed: student-russell simmons → student-russell_simmons
# ✅ Renamed: student-sachiko yamada → student-sachiko_yamada
# ✅ Renamed: student-saddam hussein → student-saddam_hussein
# ✅ Renamed: student-sally field → student-sally_field
# ✅ Renamed: student-sally kirkland → student-sally_kirkland
# ✅ Renamed: student-salma hayek → student-salma_hayek
# ✅ Renamed: student-samuel waksal → student-samuel_waksal
# ✅ Renamed: student-sandra bullock → student-sandra_bullock
# ✅ Renamed: student-sarah hughes → student-sarah_hughes
# ✅ Renamed: student-sarah jessica parker → student-sarah_jessica_parker
# ✅ Renamed: student-scott mcclellan → student-scott_mcclellan
# ✅ Renamed: student-scott peterson → student-scott_peterson
# ✅ Renamed: student-sean okeefe → student-sean_okeefe
# ✅ Renamed: student-sebastien grosjean → student-sebastien_grosjean
# ✅ Renamed: student-sepp blatter → student-sepp_blatter
# ✅ Renamed: student-serena williams → student-serena_williams
# ✅ Renamed: student-sergei ivanov → student-sergei_ivanov
# ✅ Renamed: student-sergey lavrov → student-sergey_lavrov
# ✅ Renamed: student-sergio vieira de mello → student-sergio_vieira_de_mello
# ✅ Renamed: student-sharon stone → student-sharon_stone
# ✅ Renamed: student-sheila copps → student-sheila_copps
# ✅ Renamed: student-sheryl crow → student-sheryl_crow
# ✅ Renamed: student-shimon peres → student-shimon_peres
# ✅ Renamed: student-sila calderon → student-sila_calderon
# ✅ Renamed: student-silvan shalom → student-silvan_shalom
# ✅ Renamed: student-silvio berlusconi → student-silvio_berlusconi
# ✅ Renamed: student-slobodan milosevic → student-slobodan_milosevic
# ✅ Renamed: student-sonia gandhi → student-sonia_gandhi
# ✅ Renamed: student-sophia loren → student-sophia_loren
# ✅ Renamed: student-sourav ganguly → student-sourav_ganguly
# ✅ Renamed: student-spencer abraham → student-spencer_abraham
# ✅ Renamed: student-steffi graf → student-steffi_graf
# ✅ Renamed: student-steve lavin → student-steve_lavin
# ✅ Renamed: student-steve nash → student-steve_nash
# ✅ Renamed: student-steven spielberg → student-steven_spielberg
# ✅ Renamed: student-susan sarandon → student-susan_sarandon
# ✅ Renamed: student-susilo bambang yudhoyono → student-susilo_bambang_yudhoyono
# ✅ Renamed: student-sylvester stallone → student-sylvester_stallone
# ✅ Renamed: student-taha yassin ramadan → student-taha_yassin_ramadan
# ✅ Renamed: student-tang jiaxuan → student-tang_jiaxuan
# ✅ Renamed: student-tariq aziz → student-tariq_aziz
# ✅ Renamed: student-thabo mbeki → student-thabo_mbeki
# ✅ Renamed: student-thaksin shinawatra → student-thaksin_shinawatra
# ✅ Renamed: student-thomas fargo → student-thomas_fargo
# ✅ Renamed: student-thomas obrien → student-thomas_obrien
# ✅ Renamed: student-tiger woods → student-tiger_woods
# ✅ Renamed: student-tim allen → student-tim_allen
# ✅ Renamed: student-tim duncan → student-tim_duncan
# ✅ Renamed: student-tim henman → student-tim_henman
# ✅ Renamed: student-tim robbins → student-tim_robbins
# ✅ Renamed: student-todd haynes → student-todd_haynes
# ✅ Renamed: student-tom craddick → student-tom_craddick
# ✅ Renamed: student-tom crean → student-tom_crean
# ✅ Renamed: student-tom cruise → student-tom_cruise
# ✅ Renamed: student-tom daschle → student-tom_daschle
# ✅ Renamed: student-tom hanks → student-tom_hanks
# ✅ Renamed: student-tom harkin → student-tom_harkin
# ✅ Renamed: student-tom ridge → student-tom_ridge
# ✅ Renamed: student-tommy franks → student-tommy_franks
# ✅ Renamed: student-tommy haas → student-tommy_haas
# ✅ Renamed: student-tommy thompson → student-tommy_thompson
# ✅ Renamed: student-tony bennett → student-tony_bennett
# ✅ Renamed: student-tony blair → student-tony_blair
# ✅ Renamed: student-tony shalhoub → student-tony_shalhoub
# ✅ Renamed: student-tony stewart → student-tony_stewart
# ✅ Renamed: student-trent lott → student-trent_lott
# ✅ Renamed: student-tung chee-hwa → student-tung_chee-hwa
# ✅ Renamed: student-vaclav havel → student-vaclav_havel
# ✅ Renamed: student-valentino rossi → student-valentino_rossi
# ✅ Renamed: student-valery giscard destaing → student-valery_giscard_destaing
# ✅ Renamed: student-vanessa incontrada → student-vanessa_incontrada
# ✅ Renamed: student-vanessa redgrave → student-vanessa_redgrave
# ✅ Renamed: student-venus williams → student-venus_williams
# ✅ Renamed: student-vicente fernandez → student-vicente_fernandez
# ✅ Renamed: student-vicente fox → student-vicente_fox
# ✅ Renamed: student-victoria clarke → student-victoria_clarke
# ✅ Renamed: student-vince carter → student-vince_carter
# ✅ Renamed: student-vincent brooks → student-vincent_brooks
# ✅ Renamed: student-vitali klitschko → student-vitali_klitschko
# ✅ Renamed: student-vladimir putin → student-vladimir_putin
# ✅ Renamed: student-vojislav kostunica → student-vojislav_kostunica
# ✅ Renamed: student-walter mondale → student-walter_mondale
# ✅ Renamed: student-wayne ferreira → student-wayne_ferreira
# ✅ Renamed: student-wayne gretzky → student-wayne_gretzky
# ✅ Renamed: student-wen jiabao → student-wen_jiabao
# ✅ Renamed: student-william bulger → student-william_bulger
# ✅ Renamed: student-william donaldson → student-william_donaldson
# ✅ Renamed: student-william ford jr → student-william_ford_jr
# ✅ Renamed: student-william macy → student-william_macy
# ✅ Renamed: student-win aung → student-win_aung
# ✅ Renamed: student-winona ryder → student-winona_ryder
# ✅ Renamed: student-wolfgang schuessel → student-wolfgang_schuessel
# ✅ Renamed: student-woody allen → student-woody_allen
# ✅ Renamed: student-xanana gusmao → student-xanana_gusmao
# ✅ Renamed: student-xavier malisse → student-xavier_malisse
# ✅ Renamed: student-yao ming → student-yao_ming
# ✅ Renamed: student-yasar yakis → student-yasar_yakis
# ✅ Renamed: student-yashwant sinha → student-yashwant_sinha
# ✅ Renamed: student-yasser arafat → student-yasser_arafat
# ✅ Renamed: student-yevgeny kafelnikov → student-yevgeny_kafelnikov
# ✅ Renamed: student-yoko ono → student-yoko_ono
# ✅ Renamed: student-yoriko kawaguchi → student-yoriko_kawaguchi
# ✅ Renamed: student-yu shyi-kun → student-yu_shyi-kun
# ✅ Renamed: student-zhang ziyi → student-zhang_ziyi
# ✅ Renamed: student-zhu rongji → student-zhu_rongji
# ✅ Renamed: student-zinedine zidane → student-zinedine_zidane
# ✅ Renamed: student-zoran djindjic → student-zoran_djindjic
#
# 🎉 All matching folder names have been updated.

# %%
import os
import shutil

# -------- CONFIG --------
source_folder = 'lfw_imposter'       # Jahan images hain
destination_folder = 'structured_lfw_imposters'  # Jahan images jaani chahiye
prefix = 'student-lfw'                # Base name for folders

# Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Get list of images
image_list = [f for f in os.listdir(source_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]

# Start counter
counter = 1

# Process each image
for img_name in image_list:
    # Create new folder like student-lfw_1, student-lfw_2, ...
    folder_name = f"{prefix}_{counter}"
    folder_path = os.path.join(destination_folder, folder_name)
    os.makedirs(folder_path, exist_ok=True)

    # Copy and rename image
    src_img_path = os.path.join(source_folder, img_name)
    dst_img_name = f"{folder_name}_1.jpg"  # You can change suffix if needed
    dst_img_path = os.path.join(folder_path, dst_img_name)

    shutil.copy(src_img_path, dst_img_path)

    print(f"Moved {img_name} → {dst_img_path}")
    counter += 1

# %%
import os
import shutil
import random

# Original folder containing 12 imposter folders
original_path = 'actors'  # ← change this
all_folders = [f for f in os.listdir(original_path) if os.path.isdir(os.path.join(original_path, f))]

# Sort for consistency
all_folders.sort()

# Loop through and rename + retain 10 images
for idx, folder in enumerate(all_folders, start=1):
    old_path = os.path.join(original_path, folder)
    new_folder_name = f"student-imposter_{idx}"
    new_path = os.path.join(original_path, new_folder_name)

    # Rename the folder
    os.rename(old_path, new_path)

    # List all images inside
    images = [img for img in os.listdir(new_path) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if len(images) <= 10:
        continue  # If already ≤10, skip

    # Randomly keep only 10
    images_to_keep = set(random.sample(images, 10))

    for img in images:
        if img not in images_to_keep:
            os.remove(os.path.join(new_path, img))

print("✅ Done! All folders renamed and trimmed to 10 images each.")
# Out:
# ✅ Done! All folders renamed and trimmed to 10 images each.
